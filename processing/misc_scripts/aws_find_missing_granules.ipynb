# %%
import numpy as np
import json
import boto3
import botocore  
from pathlib import Path
from pprint import pprint

import json
import boto3
import botocore
from boto3.session import Session

from collections import Counter
import datetime

# %%
def get_unique_task_names(task_dir):
    all_json_task_files = list(Path(task_dir).glob('*json'))
   
    unique_task_names = []
    
    for tf in all_json_task_files:
        tmp = str(tf).split('/')[-1].split('_task')[0]
        unique_task_names.append(tmp)
        
    unique_task_names= set(unique_task_names)
    
    return np.sort(list(unique_task_names))

# %%
def get_all_tasks_for_task_name(task_dir, task_name):
    
    print('getting all tasks for ', task_name)
    all_json_task_files = list(Path(task_dir).glob('*' + task_name + '*json'))
    return all_json_task_files

# %%
def combine_tasks(json_task_files): 

    print('... combining tasks from n json task files n=', len(json_task_files))
    combined = []
    
    for file in json_task_files:
        with open(file, 'r') as f:
            try:
                data = json.load(f)
                combined = combined + data
            except json.JSONDecodeError as e:
                print(f"Skipping {file}: {e}")

    return combined

# %%
def find_duplicate_granules(granule_list):
    counts = Counter(granule_list)

    # Extract duplicates
    duplicates = [item for item, count in counts.items() if count > 1]

    print("!Duplicates:", duplicates)
    print('\n')

# %%
def get_s3_file_info(s3_url):
    if not s3_url.startswith("s3://"):
        return (False, 0)
        
    bucket, key = s3_url[5:].split('/', 1)
    
    try:
        response = s3.head_object(Bucket=bucket, Key=key)
        size = response['ContentLength']
        return (True, size)
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            return (False, 0)
        else:
            raise  # Unexpected error

# %%
def s3_exists(s3_url):
    
    if not s3_url.startswith("s3://"):
        return False
    parts = s3_url[5:].split('/', 1)
    bucket = parts[0]
    key = parts[1]

    try:
        s3.head_object(Bucket=bucket, Key=key)
        return True
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            return False
        else:
            raise  # Raise unexpected errors

# %%
def count_files_in_s3_path(s3, bucket, prefix, extension='nc'):
    
    # bucket name
    # prefix (the directory equivalent of s3 buckets)
    # extension = ".nc"            # File extension to filter by
    # s3 = boto3.client("s3")

    print(bucket, prefix)
    paginator = s3.get_paginator("list_objects_v2")
    page_iterator = paginator.paginate(Bucket=bucket, Prefix=prefix)
    
    count = 0
    for page in page_iterator:
        for obj in page.get("Contents", []):
            key = obj["Key"]
            if key.endswith(extension):
                count += 1
    
    print(f"{count} {extension} files found in s3://{bucket}/{prefix}")
    return count

# %%
def get_all_filenames_in_bucket(s3, bucket, prefix):
        
    paginator = s3.get_paginator("list_objects_v2")
    page_iterator = paginator.paginate(Bucket=bucket, Prefix=prefix)
    
    all_keys = []
    
    for page in page_iterator:
        for obj in page.get("Contents", []):
            all_keys.append(obj["Key"])

    return all_keys

# %%
def save_new_task_list(json_output_path, task_name, task_list):

    print('saving # tasks ', len(task_list))
    
    output_filename = json_output_path / str(task_name + '_redo.json')
    print(output_filename)
        
    with open(output_filename, "w") as f:
        json.dump(task_list, f, indent=2)

# %%
def create_redo_task_list(task_dir, task_name, new_task_dir, s3):


    print ('\n\n---------------------------------------------------------------------')           
    print (' PROCESSING ', task_name)
    print ('---------------------------------------------------------------------\n')           
        
    # how many parts is this task type divided into?
    # the number of task files of this task type

    # get the list of json files associated with this take type
    # (dataset - grid - averaging period)
    json_task_files = np.sort(list(get_all_tasks_for_task_name(task_dir, task_name)))
    
    print('# of task files for this task type ', len(json_task_files))
    print('\n')
    pprint(json_task_files[:5])
        
    # combine all separate tasks into a single giant list
    # one item per task
    
    # combined tasks (cts)
    cts = combine_tasks(json_task_files)
    
    # extract the granule name from the combined tasks
    granule_filepaths = np.sort([c['granule'] for c in cts])
    print('# of granule filepaths in the task json files ', len(granule_filepaths))
    
    # report duplicate granules 
    find_duplicate_granules(granule_filepaths)
    
    # make a dictionary with the granule name as key
    # and the associated task json text block as the entry
    granule_dict = dict()
    
    # go through all tasks
    for ct in cts:
        # add the task to the dictionary
        # use the final granule filepath as the key
        granule_dict[ct['granule']] = ct
    
    granule_dict_keys = np.sort(list(granule_dict.keys()))
    
    num_granules_in_task = len(granule_dict_keys)
    print('# unique granules in tasks ', num_granules_in_task)
    
    # get the s3 bucket name and prefix from the first file in the granules list
    first_granule_path = Path(granule_filepaths[0])
    
    # ... the s3 bucket name and prefix
    bucket = str(first_granule_path.parent).split('/')[1]; 
    prefix = str(first_granule_path.parent).split(bucket)[1][1:]
    
    # get a list of filenames in the destination bucket
    files_in_bucket = get_all_filenames_in_bucket(s3, bucket, prefix)
    files_in_bucket_full_path = ['s3://' + bucket + '/' + f for f in files_in_bucket]
    
    num_files_in_bucket = len(files_in_bucket_full_path)
    print('found # files in bucket ', num_files_in_bucket)
    
    # Determine which granules are missing and which are present in the destination bucket
    found_granules = []
    missing_granules = []
    
    # loop through all of the granule filepaths extracted from the json task lists
    for g in granule_dict_keys:
        # is the granule filepath present in the bucket
        if g in files_in_bucket_full_path:
            found_granules.append(g) # found
        else:
            missing_granules.append(g) # not found
    
    print('found_granules   ', len(found_granules))
    print('missing_granules ' , len(missing_granules))
    
    # construct a list of tasks the need to be resubmitted
    tasks_to_redo = []
    
    if len(missing_granules) > 0:
        print('\nsome granules missing, adding missing tasks')
            
        for granule_filename in missing_granules:
            tasks_to_redo.append(granule_dict[granule_filename])
    
        save_new_task_list(new_task_dir, task_name, tasks_to_redo)
    
    else:
        print('\nall granules present, nothing to redo')

# %% [markdown]
# # Begin

# %%
# Set your AWS profile name here
AWS_PROFILE = "saml-pub"

# Start a boto3 session using that profile
session = Session(profile_name=AWS_PROFILE)
s3 = session.client('s3')

# %%
# Local path that has all task json files

task_dir = Path('/home/ifenty/aws_test/all_tasks')

# path for new tasks for missing granules
new_task_dir = task_dir / str("missing_" + datetime.datetime.now().strftime('%Y%m%dT%H%M%S'))

# %%
print(new_task_dir)
try:
    new_task_dir.mkdir(parents=True, exist_ok=True)
except FileExistsError:
    print(f"Directory already exists: {new_task_dir}")
# Out:
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737

# %%
# get the unique task names
# that is dataset / grid / time period

unique_task_names = get_unique_task_names(task_dir)
pprint(unique_task_names)
# Out:
# array(['ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY',
#        'ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON',
#        'ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY',
#        'ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON',
#        'ICE_FRONT_FLUX_native_AVG_MON', 'ICE_SHELF_FLUX_native_AVG_MON',
#        'OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON',
#        'OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON',
#        'OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON',
#        'OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON',
#        'OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON',
#        'OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON',
#        'OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY',
#        'OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON',
#        'OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY',
#        'OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON',
#        'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY',
#        'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON',
#        'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY',
#        'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON',
#        'OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY',
#        'OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON',
#        'OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY',
#        'OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON',
#        'OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY',
#        'OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON',
#        'OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY',
#        'OCEAN_BOLUS_VELOCITY_latlon_AVG_MON',
#        'OCEAN_BOLUS_VELOCITY_native_AVG_DAY',
#        'OCEAN_BOLUS_VELOCITY_native_AVG_MON',
#        'OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY',
#        'OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON',
#        'OCEAN_BOTTOM_PRESSURE_native_AVG_DAY',
#        'OCEAN_BOTTOM_PRESSURE_native_AVG_MON',
#        'OCEAN_BOTTOM_PRESSURE_native_SNAP',
#        'OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY',
#        'OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON',
#        'OCEAN_DENS_STRAT_PRESS_native_AVG_DAY',
#        'OCEAN_DENS_STRAT_PRESS_native_AVG_MON',
#        'OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY',
#        'OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON',
#        'OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY',
#        'OCEAN_MIXED_LAYER_DEPTH_native_AVG_MON',
#        'OCEAN_SALINITY_FLUX_native_AVG_DAY',
#        'OCEAN_SALINITY_FLUX_native_AVG_MON',
#        'OCEAN_TEMPERATURE_FLUX_native_AVG_DAY',
#        'OCEAN_TEMPERATURE_FLUX_native_AVG_MON',
#        'OCEAN_TEMPERATURE_SALINITY_latlon_AVG_DAY',
#        'OCEAN_TEMPERATURE_SALINITY_latlon_AVG_MON',
#        'OCEAN_TEMPERATURE_SALINITY_native_AVG_DAY',
#        'OCEAN_TEMPERATURE_SALINITY_native_AVG_MON',
#        'OCEAN_TEMPERATURE_SALINITY_native_SNAP',
#        'OCEAN_VELOCITY_latlon_AVG_DAY', 'OCEAN_VELOCITY_latlon_AVG_MON',
#        'OCEAN_VELOCITY_native_AVG_DAY', 'OCEAN_VELOCITY_native_AVG_MON',
#        'OCEAN_VOLUME_FLUX_native_AVG_DAY',
#        'OCEAN_VOLUME_FLUX_native_AVG_MON',
#        'SEA_ICE_CONC_THICKNESS_latlon_AVG_DAY',
#        'SEA_ICE_CONC_THICKNESS_latlon_AVG_MON',
#        'SEA_ICE_CONC_THICKNESS_native_AVG_DAY',
#        'SEA_ICE_CONC_THICKNESS_native_AVG_MON',
#        'SEA_ICE_CONC_THICKNESS_native_SNAP',
#        'SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_DAY',
#        'SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON',
#        'SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY',
#        'SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON',
#        'SEA_ICE_THERMO_BUDG_native_AVG_MON',
#        'SEA_ICE_VELOCITY_latlon_AVG_DAY',
#        'SEA_ICE_VELOCITY_latlon_AVG_MON',
#        'SEA_ICE_VELOCITY_native_AVG_DAY',
#        'SEA_ICE_VELOCITY_native_AVG_MON', 'SEA_ICE_VELOCITY_native_SNAP',
#        'SEA_SURFACE_HEIGHT_latlon_AVG_DAY',
#        'SEA_SURFACE_HEIGHT_latlon_AVG_MON',
#        'SEA_SURFACE_HEIGHT_native_AVG_DAY',
#        'SEA_SURFACE_HEIGHT_native_AVG_MON',
#        'SEA_SURFACE_HEIGHT_native_SNAP'], dtype='<U46')

# %% [markdown]
# # Find the missing granules for each unique task name

# %%
for task_name in unique_task_names:
    
    create_redo_task_list(task_dir, task_name, new_task_dir, s3)
# Out:
# ---------------------------------------------------------------------
#  PROCESSING  ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/ATM_SURFACE_TEMP_HUM_WIND_PRES/ATM_SURFACE_TEMP_HUM_WIND_PRES_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10012
# found_granules    10012
# missing_granules  214
#
# some granules missing, adding missing tasks
# saving # tasks  214
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/ATM_SURFACE_TEMP_HUM_WIND_PRES/ATM_SURFACE_TEMP_HUM_WIND_PRES_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ATM_SURFACE_TEMP_HUM_WIND_PRES_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  ICE_FRONT_FLUX_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  ICE_FRONT_FLUX_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/ICE_FRONT_FLUX_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ICE_FRONT_FLUX_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ICE_FRONT_FLUX_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ICE_FRONT_FLUX_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  ICE_SHELF_FLUX_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  ICE_SHELF_FLUX_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/ICE_SHELF_FLUX_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ICE_SHELF_FLUX_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ICE_SHELF_FLUX_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/ICE_SHELF_FLUX_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_X_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_ADV_TEND_Y_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_X_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_DISS_TEND_Y_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_X_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_3D_MOMENTUM_TEND_Y_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_AND_ICE_SURFACE_FW_FLUX/OCEAN_AND_ICE_SURFACE_FW_FLUX_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_AND_ICE_SURFACE_FW_FLUX/OCEAN_AND_ICE_SURFACE_FW_FLUX_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_FW_FLUX_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_AND_ICE_SURFACE_HEAT_FLUX/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_AND_ICE_SURFACE_HEAT_FLUX/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_HEAT_FLUX_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_AND_ICE_SURFACE_STRESS/OCEAN_AND_ICE_SURFACE_STRESS_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_AND_ICE_SURFACE_STRESS/OCEAN_AND_ICE_SURFACE_STRESS_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_AND_ICE_SURFACE_STRESS_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_BOLUS_STREAMFUNCTION/OCEAN_BOLUS_STREAMFUNCTION_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  9978
# found_granules    9978
# missing_granules  248
#
# some granules missing, adding missing tasks
# saving # tasks  248
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_STREAMFUNCTION_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_BOLUS_VELOCITY/OCEAN_BOLUS_VELOCITY_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10170
# found_granules    10170
# missing_granules  56
#
# some granules missing, adding missing tasks
# saving # tasks  56
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_BOLUS_VELOCITY_latlon_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOLUS_VELOCITY_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOLUS_VELOCITY_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOLUS_VELOCITY_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOLUS_VELOCITY_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_BOLUS_VELOCITY/OCEAN_BOLUS_VELOCITY_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10202
# found_granules    10202
# missing_granules  24
#
# some granules missing, adding missing tasks
# saving # tasks  24
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_BOLUS_VELOCITY_native_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOLUS_VELOCITY_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOLUS_VELOCITY_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOLUS_VELOCITY_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_BOTTOM_PRESSURE/OCEAN_BOTTOM_PRESSURE_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10048
# found_granules    10048
# missing_granules  178
#
# some granules missing, adding missing tasks
# saving # tasks  178
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_BOTTOM_PRESSURE_latlon_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOTTOM_PRESSURE_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOTTOM_PRESSURE_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_BOTTOM_PRESSURE/OCEAN_BOTTOM_PRESSURE_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10115
# found_granules    10115
# missing_granules  111
#
# some granules missing, adding missing tasks
# saving # tasks  111
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_BOTTOM_PRESSURE_native_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOTTOM_PRESSURE_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOTTOM_PRESSURE_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_BOTTOM_PRESSURE_native_SNAP
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_BOTTOM_PRESSURE_native_SNAP
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_SNAP_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_SNAP_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_SNAP_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_SNAP_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_BOTTOM_PRESSURE_native_SNAP_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10226
# !Duplicates: []
#
#
# # unique granules in tasks  10226
# found # files in bucket  10184
# found_granules    10184
# missing_granules  42
#
# some granules missing, adding missing tasks
# saving # tasks  42
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_BOTTOM_PRESSURE_native_SNAP_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_DENS_STRAT_PRESS/OCEAN_DENS_STRAT_PRESS_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10082
# found_granules    10082
# missing_granules  144
#
# some granules missing, adding missing tasks
# saving # tasks  144
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_DENS_STRAT_PRESS_latlon_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_DENS_STRAT_PRESS_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_DENS_STRAT_PRESS_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/OCEAN_DENS_STRAT_PRESS/OCEAN_DENS_STRAT_PRESS_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10138
# found_granules    10138
# missing_granules  88
#
# some granules missing, adding missing tasks
# saving # tasks  88
# /home/ifenty/aws_test/all_tasks/missing_20250510T214737/OCEAN_DENS_STRAT_PRESS_native_AVG_DAY_redo.json
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_DENS_STRAT_PRESS_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_DENS_STRAT_PRESS_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_DENS_STRAT_PRESS_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/OCEAN_MIXED_LAYER_DEPTH/OCEAN_MIXED_LAYER_DEPTH_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/OCEAN_MIXED_LAYER_DEPTH_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# ...
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/SEA_ICE_HORIZ_VOLUME_FLUX/SEA_ICE_HORIZ_VOLUME_FLUX_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_HORIZ_VOLUME_FLUX_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/SEA_ICE_SALT_PLUME_FLUX/SEA_ICE_SALT_PLUME_FLUX_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_SALT_PLUME_FLUX_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_THERMO_BUDG_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_THERMO_BUDG_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_THERMO_BUDG_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_THERMO_BUDG_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_THERMO_BUDG_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_THERMO_BUDG_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_VELOCITY_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_VELOCITY_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/SEA_ICE_VELOCITY/SEA_ICE_VELOCITY_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_VELOCITY_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_VELOCITY_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_VELOCITY_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_VELOCITY_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/SEA_ICE_VELOCITY/SEA_ICE_VELOCITY_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_VELOCITY_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_VELOCITY_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_ICE_VELOCITY_native_SNAP
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_ICE_VELOCITY_native_SNAP
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_SNAP_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_SNAP_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_SNAP_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_SNAP_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_ICE_VELOCITY_native_SNAP_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10226
# !Duplicates: []
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_SURFACE_HEIGHT_latlon_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_SURFACE_HEIGHT_latlon_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/latlon/day_mean/SEA_SURFACE_HEIGHT/SEA_SURFACE_HEIGHT_day_mean_2019-12-31_ECCO_V4r5_latlon_0p50deg.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_SURFACE_HEIGHT_latlon_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_SURFACE_HEIGHT_latlon_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_latlon_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_SURFACE_HEIGHT_native_AVG_DAY
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_SURFACE_HEIGHT_native_AVG_DAY
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_DAY_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_DAY_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_DAY_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_DAY_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_DAY_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10227
# !Duplicates: ['s3://ecco-dataset-production-datasets/V4r5/native/day_mean/SEA_SURFACE_HEIGHT/SEA_SURFACE_HEIGHT_day_mean_2019-12-31_ECCO_V4r5_native_llc0090.nc']
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_SURFACE_HEIGHT_native_AVG_MON
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_SURFACE_HEIGHT_native_AVG_MON
# # of task files for this task type  4
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_MON_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_MON_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_MON_task_2.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_AVG_MON_task_3.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 4
# # of granule filepaths in the task json files  336
# !Duplicates: []
#
#
# # unique granules in tasks  336
# found # files in bucket  336
# found_granules    336
# missing_granules  0
#
# all granules present, nothing to redo
#
#
# ---------------------------------------------------------------------
#  PROCESSING  SEA_SURFACE_HEIGHT_native_SNAP
# ---------------------------------------------------------------------
#
# getting all tasks for  SEA_SURFACE_HEIGHT_native_SNAP
# # of task files for this task type  103
#
#
# array([PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_SNAP_task_0.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_SNAP_task_1.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_SNAP_task_10.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_SNAP_task_100.json'),
#        PosixPath('/home/ifenty/aws_test/all_tasks/SEA_SURFACE_HEIGHT_native_SNAP_task_101.json')],
#       dtype=object)
# ... combining tasks from n json task files n= 103
# # of granule filepaths in the task json files  10226
# !Duplicates: []
#
#
# # unique granules in tasks  10226
# found # files in bucket  10226
# found_granules    10226
# missing_granules  0
#
# all granules present, nothing to redo
